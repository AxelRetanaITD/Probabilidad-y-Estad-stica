# %% [markdown]
# <a href="https://colab.research.google.com/github/AxelRetanaITD/Probabilidad-y-Estad-stica/blob/main/UNIDAD1/PRACTICAS_1Y2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
# #Probabilidad y Estadística
#
# ##Unidad 1
#
# Practicas #1 y #2
#
# Grupo 2Y
#
# Alumno: Rodrigo Axel Retana Diaz
#
# Maestro:DR. José Gabriel Rodríguez Rivas

# %%
from statistics import *
# Lista de calificaciones del grupo a de probabilidad y estadística
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print("Grupo A: ",grupoa)
#La función type nos devuelve el tipo de dato de la variable
type(grupoa)
#Sacar la media de las califcaciones con una formula
promedio = sum(grupoa) / len(grupoa)
print("El promedio es: ",promedio)
#Utilizar la función mean que esta en la librería statistics para sacar el promedio
promedio2 = mean(grupoa)
print("El promedio usando la función mean: ",promedio2)
# Determinar el valor de la mediana con la función median
mediana = median(grupoa)
print("La mediana es: ",mediana)
# Determinar el valor de la moda con la función mode
moda = mode(grupoa)
print("La moda es: ",moda)
#En caso de que exista más de una moda, se puede enviar la función multimoda para sacar
# las múltiples modas que puedan existir
moda2 = multimode(grupoa)
print("Las multiples modas son: ",moda2)
# Out:
# Grupo A:  [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# El promedio es:  75.33333333333333
# El promedio usando la función mean:  75.33333333333333
# La mediana es:  76.5
# La moda es:  70
# Las multiples modas son:  [70, 100]

# %%
#Ejemplo 2
# Definimos una variable llamada tiempos100mts de tipo lista, que contiene los
# tiempos que tardaron los 10 alumnos para correr los 100 metros
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
# Desplegamos los valores de la lista
print(tiempos100mts)
# Usamos la función mean para calcular el tiempo promedio de la lista de valores
print("El promedio de los corredores es: ", mean(tiempos100mts))
# Usamos una variable llamada mediana para calcular la mediana de la lista con la función
# median
mediana=median(tiempos100mts)
print("La mediana de los tiempos de los corredores es: ",mediana)
# Definimos una variable llamada moda para calcular la moda de la lista con una función
# mode
moda=mode(tiempos100mts)
print("La moda de los tiempos es: ", moda)
multimodas=multimode(tiempos100mts)
print("La moda de los tiempos es: ",multimodas)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# El promedio de los corredores es:  17.322
# La mediana de los tiempos de los corredores es:  17.2
# La moda de los tiempos es:  15.1
# La moda de los tiempos es:  [15.1, 17.2]

# %%
#Histogramas de 2 grupos
# Libreria para genarar números aleatorios
import random
fabrica1=[]
for i in range(100):
  numero_aleatorio= round( random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
fabrica2=[]
for x in range(100):
  numero_aleatorio2= round( random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Librería de python para graficar valores
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Producción diaria de la fabrica 1")
plt.show()
plt.hist(fabrica2)
plt.title("Producción diaria de la fábrica 2")
plt.show()
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("Valores de la fábrica 1")
print("La media es = ",media1)
print("La mediana es = ", mediana1)
print("La moda es = ", moda1)
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Valores de la fábrica 2")
print("La media es = ",mediana2)
print("La mediana es = ", mediana2)
print("La moda es = ", moda2)
# Generar 2 subplot de 1 renglón por 2 columnas para desplegar los 2 histogramas,
# una al lado de la otra
fig, (ax1, ax2)=plt.subplots(nrows= 1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
# Out:
# [92.93, 75.63, 74.57, 98.65, 72.98, 98.31, 54.0, 96.96, 82.36, 90.05, 83.8, 87.16, 82.69, 92.31, 88.59, 62.89, 62.65, 74.26, 72.68, 53.66, 79.61, 87.85, 81.15, 80.73, 74.3, 65.98, 55.74, 97.55, 74.0, 88.87, 79.43, 99.26, 77.31, 82.17, 66.02, 68.81, 63.34, 85.59, 51.57, 61.31, 74.56, 87.44, 51.97, 86.38, 60.02, 99.49, 56.85, 76.34, 58.05, 96.27, 50.15, 86.31, 81.09, 78.28, 85.1, 59.79, 92.98, 84.85, 98.35, 80.39, 54.35, 86.37, 70.44, 73.28, 58.62, 64.21, 86.46, 68.04, 91.23, 97.96, 52.46, 73.6, 68.43, 94.55, 67.67, 53.74, 87.33, 71.86, 89.61, 88.75, 60.19, 78.36, 88.12, 52.27, 54.13, 65.97, 91.6, 71.39, 90.26, 57.2, 54.09, 74.57, 70.92, 57.58, 80.66, 61.52, 75.95, 95.82, 97.06, 73.47]
# ...
